# %%
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install html5lib
# Out:
# Requirement already satisfied: pandas in C:\Users\Jhon\anaconda3\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\Jhon\anaconda3\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Jhon\anaconda3\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Jhon\anaconda3\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Jhon\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in C:\Users\Jhon\anaconda3\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Jhon\anaconda3\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Jhon\anaconda3\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Jhon\anaconda3\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Jhon\anaconda3\Lib\site-packages (from requests) (2026.6.17)
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in C:\Users\Jhon\anaconda3\Lib\site-packages (from bs4) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\Jhon\anaconda3\Lib\site-packages (from beautifulsoup4->bs4) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Jhon\anaconda3\Lib\site-packages (from beautifulsoup4->bs4) (4.16.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in C:\Users\Jhon\anaconda3\Lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in C:\Users\Jhon\anaconda3\Lib\site-packages (from html5lib) (0.5.1)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/amazon_data_webpage.html'
html_data = requests.get(url).text

# %%
soup = BeautifulSoup(html_data, 'html.parser')

# %%
amazon_data = pd.DataFrame(columns=["Date", "Open", "High", "Low", "Close", "Volume"])

for row in soup.find("tbody").find_all("tr"):
    col = row.find_all("td")
    date = col[0].text
    Open = col[1].text
    high = col[2].text
    low = col[3].text
    close = col[4].text
    adj_close = col[5].text
    volume = col[6].text
    
    amazon_data = pd.concat([amazon_data, pd.DataFrame({"Date":[date], "Open":[Open], "High":[high], "Low":[low], "Close":[close], "Adj Close":[adj_close], "Volume":[volume]})], ignore_index=True)

# %%
amazon_data.head()
# Out:
#            Date      Open      High       Low     Close       Volume Adj Close
# 0  Jan 01, 2021  3,270.00  3,363.89  3,086.00  3,206.20   71,528,900  3,206.20
# 1  Dec 01, 2020  3,188.50  3,350.65  3,072.82  3,256.93   77,556,200  3,256.93
# 2  Nov 01, 2020  3,061.74  3,366.80  2,950.12  3,168.04   90,810,500  3,168.04
# 3  Oct 01, 2020  3,208.00  3,496.24  3,019.00  3,036.15  116,226,100  3,036.15
# 4  Sep 01, 2020  3,489.58  3,552.25  2,871.00  3,148.73  115,899,300  3,148.73
